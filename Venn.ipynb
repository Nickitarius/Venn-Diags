# %%
import pandas as pd
from matplotlib import pyplot as plt
from venn import venn

df_common_genes = pd.read_excel("Common genes 4 strains Pseudomonas.xlsx")
df = pd.read_excel("Gene presence absence.xlsx")
data = dict()

for col in ['P_PLB05', 'P_oryz', 'P_psych', 'P_rhyz']:
    data[col] = set(df[df[col] == 1][col].index.to_list())

venn(data)
# Out:
# 4835
